# %% [markdown]
# <a href="https://colab.research.google.com/github/ChangeEngine/Intro-to-ML--Group-1--Final-Project/blob/main/02_baseline_model.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from pathlib import Path

# Try to locate the data/ folder (works from root or from notebooks/)
DATA_DIR = Path("data")
if not DATA_DIR.exists():
    DATA_DIR = Path("..") / "data"

print("Using data folder:", DATA_DIR.resolve())
print("Files in data/:")
for p in DATA_DIR.iterdir():
    print(" -", p.name)
# Out:
# Using data folder: /data
# Files in data/:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /tmp/ipython-input-1022891200.py in <cell line: 0>()
#       8 print("Using data folder:", DATA_DIR.resolve())
#       9 print("Files in data/:")
# ---> 10 for p in DATA_DIR.iterdir():
#      11     print(" -", p.name)
#
# /usr/lib/python3.12/pathlib.py in iterdir(self)
#    1054         special entries '.' and '..' are not included.
#    1055         """
# -> 1056         for name in os.listdir(self):
#    1057             yield self._make_child_relpath(name)
#    1058
#
# FileNotFoundError: [Errno 2] No such file or directory: '../data'
